# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv(r"C:\Users\srava\Downloads\train.csv")

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df.tail()
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# ...

# %%
df.shape
# Out:
# (614, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df['ApplicantIncome']
# Out:
# 0      5849
# 1      4583
# 2      3000
# 3      2583
# 4      6000
#        ...
# 609    2900
# 610    4106
# 611    8072
# 612    7583
# 613    4583
# Name: ApplicantIncome, Length: 614, dtype: int64

# %%
df[['ApplicantIncome','LoanAmount']]
# Out:
#      ApplicantIncome  LoanAmount
# 0               5849         NaN
# 1               4583       128.0
# 2               3000        66.0
# 3               2583       120.0
# 4               6000       141.0
# ..               ...         ...
# 609             2900        71.0
# 610             4106        40.0
# 611             8072       253.0
# 612             7583       187.0
# 613             4583       133.0
#
# [614 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
#data preprocessing

# %%
df['LoanAmount']=df['LoanAmount'].fillna(df['LoanAmount'].mean())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         614 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0  146.412162             360.0
# 1             4583             1508.0  128.000000             360.0
# 2             3000                0.0   66.000000             360.0
# 3             2583             2358.0  120.000000             360.0
# 4             6000                0.0  141.000000             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df['Gender'].mode()[0]
# Out:
# 'Male'

# %%
df['Gender']=df['Gender'].fillna(df['Gender'].mode()[0])
df['Married']=df[ 'Married'].fillna(df['Married'].mode()[0])
df['Self_Employed']=df['Self_Employed'].fillna(df['Self_Employed'].mode()[0])
df['Loan_Amount_Term']=df['Loan_Amount_Term'].fillna(df['Loan_Amount_Term'].mean())
df['Dependents']=df['Dependents'].fillna(df['Dependents'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Dependents            0
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term      0
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
print(df)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
#categorical data
import seaborn as sns
sns.countplot(df['Gender'])
plt.show()

# %%
sns.countplot(df['Dependents'])
plt.show()

# %%
sns.countplot(df['Married'])
plt.show()

# %%
sns.countplot(df.Credit_History)
plt.show()

# %%
df['Credit_History']=df['Credit_History'].astype('str')

# %%
sns.countplot(df['Credit_History'])
plt.show()

# %%
df['Total_Income']=df['ApplicantIncome']+df['CoapplicantIncome']

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0  146.412162             360.0
# 1             4583             1508.0  128.000000             360.0
# 2             3000                0.0   66.000000             360.0
# 3             2583             2358.0  120.000000             360.0
# 4             6000                0.0  141.000000             360.0
#
#   Credit_History Property_Area Loan_Status  Total_Income
# 0            1.0         Urban           Y        5849.0
# ...

# %%
df.tail()
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#     Credit_History Property_Area Loan_Status  Total_Income
# 609            1.0         Rural           Y        2900.0
# ...

# %%
df.shape
# Out:
# (614, 14)

# %%
df['ApplicantIncomeLog']=np.log(df['ApplicantIncome'])
sns.distplot(df.ApplicantIncomeLog)
plt.show()
# Out:
# C:\Users\srava\AppData\Local\Temp\ipykernel_28436\785394375.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.ApplicantIncomeLog)

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0  146.412162             360.0
# 1             4583             1508.0  128.000000             360.0
# 2             3000                0.0   66.000000             360.0
# 3             2583             2358.0  120.000000             360.0
# 4             6000                0.0  141.000000             360.0
#
#   Credit_History Property_Area Loan_Status  Total_Income  ApplicantIncomeLog
# 0            1.0         Urban           Y        5849.0            8.674026
# ...

# %%
df['CoapplicantIncomeLog']=np.log(df['CoapplicantIncome'])
sns.histplot(df['CoapplicantIncomeLog'])
plt.show()
# Out:
# C:\Users\srava\anaconda3\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
df['Loan_Amount_Log']=np.log(df['LoanAmount'])
sns.distplot(df['Loan_Amount_Log'])
plt.show()
# Out:
# C:\Users\srava\AppData\Local\Temp\ipykernel_28436\4285763448.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Loan_Amount_Log'])

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0  146.412162             360.0
# 1             4583             1508.0  128.000000             360.0
# 2             3000                0.0   66.000000             360.0
# 3             2583             2358.0  120.000000             360.0
# 4             6000                0.0  141.000000             360.0
#
#   Credit_History Property_Area Loan_Status  Total_Income  ApplicantIncomeLog  \
# 0            1.0         Urban           Y        5849.0            8.674026
# ...

# %%
df['Total_Income_Log']=np.log(df['Total_Income'])
sns.distplot(df['Total_Income_Log'])
plt.show()
# Out:
# C:\Users\srava\AppData\Local\Temp\ipykernel_28436\1694370654.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Total_Income_Log'])

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0  146.412162             360.0
# 1             4583             1508.0  128.000000             360.0
# 2             3000                0.0   66.000000             360.0
# 3             2583             2358.0  120.000000             360.0
# 4             6000                0.0  141.000000             360.0
#
#   Credit_History Property_Area Loan_Status  Total_Income  ApplicantIncomeLog  \
# 0            1.0         Urban           Y        5849.0            8.674026
# ...

# %%
df['Loan_Amount_Term_Log']=np.log(df['Loan_Amount_Term'])
sns.displot(df["Loan_Amount_Term_Log"])
plt.show()

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0  146.412162             360.0
# 1             4583             1508.0  128.000000             360.0
# 2             3000                0.0   66.000000             360.0
# 3             2583             2358.0  120.000000             360.0
# 4             6000                0.0  141.000000             360.0
#
#   Credit_History Property_Area Loan_Status  Total_Income  ApplicantIncomeLog  \
# 0            1.0         Urban           Y        5849.0            8.674026
# ...

# %%
cols=['ApplicantIncome','CoapplicantIncome','LoanAmount','Loan_Amount_Term','Loan_ID','Total_Income','CoapplicantIncomeLog']
df=df.drop(columns=cols,axis=1)

# %%
df.head()
# Out:
#   Gender Married Dependents     Education Self_Employed Credit_History  \
# 0   Male      No          0      Graduate            No            1.0
# 1   Male     Yes          1      Graduate            No            1.0
# 2   Male     Yes          0      Graduate           Yes            1.0
# 3   Male     Yes          0  Not Graduate            No            1.0
# 4   Male      No          0      Graduate            No            1.0
#
#   Property_Area Loan_Status  ApplicantIncomeLog  Loan_Amount_Log  \
# 0         Urban           Y            8.674026         4.986426
# 1         Rural           N            8.430109         4.852030
# 2         Urban           Y            8.006368         4.189655
# 3         Urban           Y            7.856707         4.787492
# 4         Urban           Y            8.699515         4.948760
#
#    Total_Income_Log  Loan_Amount_Term_Log
# 0          8.674026              5.886104
# 1          8.714568              5.886104
# ...

# %%
df.Loan_Status.value_counts()
# Out:
# Loan_Status
# Y    422
# N    192
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Gender                614 non-null    object
#  1   Married               614 non-null    object
#  2   Dependents            614 non-null    object
#  3   Education             614 non-null    object
#  4   Self_Employed         614 non-null    object
#  5   Credit_History        614 non-null    object
#  6   Property_Area         614 non-null    object
#  7   Loan_Status           614 non-null    object
#  8   ApplicantIncomeLog    614 non-null    float64
#  9   Loan_Amount_Log       614 non-null    float64
#  10  Total_Income_Log      614 non-null    float64
#  11  Loan_Amount_Term_Log  614 non-null    float64
# dtypes: float64(4), object(8)
# memory usage: 57.7+ KB

# %%
df.Education.value_counts()
# Out:
# Education
# Graduate        480
# Not Graduate    134
# Name: count, dtype: int64

# %%
df.head()
# Out:
#   Gender Married Dependents     Education Self_Employed Credit_History  \
# 0   Male      No          0      Graduate            No            1.0
# 1   Male     Yes          1      Graduate            No            1.0
# 2   Male     Yes          0      Graduate           Yes            1.0
# 3   Male     Yes          0  Not Graduate            No            1.0
# 4   Male      No          0      Graduate            No            1.0
#
#   Property_Area Loan_Status  ApplicantIncomeLog  Loan_Amount_Log  \
# 0         Urban           Y            8.674026         4.986426
# 1         Rural           N            8.430109         4.852030
# 2         Urban           Y            8.006368         4.189655
# 3         Urban           Y            7.856707         4.787492
# 4         Urban           Y            8.699515         4.948760
#
#    Total_Income_Log  Loan_Amount_Term_Log
# 0          8.674026              5.886104
# 1          8.714568              5.886104
# ...

# %%
#get_dummies-convers a categoricl data into a dummy or indicator variable ,which are numerical representations

# %%
d1=pd.get_dummies(df['Gender'],drop_first=True)
d2=pd.get_dummies(df['Married'],drop_first=True)
d3=pd.get_dummies(df['Dependents'],drop_first=True)
d4=pd.get_dummies(df['Education'],drop_first=True)
d5=pd.get_dummies(df['Self_Employed'],drop_first=True)
d6=pd.get_dummies(df['Property_Area'],drop_first=True)

#concat
df1=pd.concat([df,d1,d2,d3,d4,d5,d6],axis=1)
df=df1;
cols=['Gender','Married','Dependents','Education','Self_Employed','Property_Area']
df=df.drop(columns=cols,axis=1)

# %%
df.head()
# Out:
#   Credit_History Loan_Status  ApplicantIncomeLog  Loan_Amount_Log  \
# 0            1.0           Y            8.674026         4.986426
# 1            1.0           N            8.430109         4.852030
# 2            1.0           Y            8.006368         4.189655
# 3            1.0           Y            7.856707         4.787492
# 4            1.0           Y            8.699515         4.948760
#
#    Total_Income_Log  Loan_Amount_Term_Log  Male    Yes      1      2     3+  \
# 0          8.674026              5.886104  True  False  False  False  False
# 1          8.714568              5.886104  True   True   True  False  False
# 2          8.006368              5.886104  True   True  False  False  False
# 3          8.505323              5.886104  True   True  False  False  False
# 4          8.699515              5.886104  True  False  False  False  False
#
#    Not Graduate    Yes  Semiurban  Urban
# 0         False  False      False   True
# ...

# %%
test=pd.read_csv(r"C:\Users\srava\Downloads\test.csv")
test.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
# 2             5000               1800       208.0             360.0
# 3             2340               2546       100.0             360.0
# 4             3276                  0        78.0             360.0
#
#    Credit_History Property_Area
# 0             1.0         Urban
# 1             1.0         Urban
# 2             1.0         Urban
# ...

# %%
test['LoanAmount']=test['LoanAmount'].fillna(test['LoanAmount'].mean())
test.isnull().sum()
# Out:
# Loan_ID               0
# Gender               11
# Married               0
# Dependents           10
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term      6
# Credit_History       29
# Property_Area         0
# dtype: int64

# %%
test['Loan_Amount_Term']=test['Loan_Amount_Term'].fillna(test['Loan_Amount_Term'].mean())
test['Credit_History']=test['Credit_History'].fillna(test['Credit_History'].mean())

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            367 non-null    object
#  1   Gender             356 non-null    object
#  2   Married            367 non-null    object
#  3   Dependents         357 non-null    object
#  4   Education          367 non-null    object
#  5   Self_Employed      344 non-null    object
#  6   ApplicantIncome    367 non-null    int64
#  7   CoapplicantIncome  367 non-null    int64
#  8   LoanAmount         367 non-null    float64
#  9   Loan_Amount_Term   367 non-null    float64
#  10  Credit_History     367 non-null    float64
#  11  Property_Area      367 non-null    object
# dtypes: float64(3), int64(2), object(7)
# memory usage: 34.5+ KB

# %%
test.isnull().sum()
# Out:
# Loan_ID               0
# Gender               11
# Married               0
# Dependents           10
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term      0
# Credit_History        0
# Property_Area         0
# dtype: int64

# %%
test['Gender']=test['Gender'].fillna(test['Gender'].mode()[0])
test['Married']=test['Married'].fillna(test['Married'].mode()[0])
test['Dependents']=test['Dependents'].fillna(test['Dependents'].mode()[0])
test['Self_Employed']=test['Self_Employed'].fillna(test['Self_Employed'].mode()[0])

# %%
test.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# dtype: int64

# %%
test['Total_Income']=test['CoapplicantIncome']+test['ApplicantIncome']
test.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
# 2             5000               1800       208.0             360.0
# 3             2340               2546       100.0             360.0
# 4             3276                  0        78.0             360.0
#
#    Credit_History Property_Area  Total_Income
# 0        1.000000         Urban          5720
# 1        1.000000         Urban          4576
# ...

# %%
test['ApplicantIncomeLog']=np.log(test['ApplicantIncome'])
test['CoapplicantIncomeLog']=np.log(test['CoapplicantIncome'])
test['Loan_Amount_Term_Log']=np.log(test['Loan_Amount_Term'])
test['LoanAmountLog']=np.log(test['LoanAmount'])
test['Total_Income_Log']=np.log(test['Total_Income'])
# Out:
# C:\Users\srava\anaconda3\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\srava\anaconda3\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
test.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
# 2             5000               1800       208.0             360.0
# 3             2340               2546       100.0             360.0
# 4             3276                  0        78.0             360.0
#
#    Credit_History Property_Area  Total_Income  ApplicantIncomeLog  \
# 0        1.000000         Urban          5720            8.651724
# ...

# %%
cols=['Total_Income','CoapplicantIncome','LoanAmount','Loan_Amount_Term','Total_Income','Loan_ID','CoapplicantIncomeLog']
test=test.drop(columns=cols,axis=1)

# %%
test.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0   Male     Yes          0      Graduate            No             5720
# 1   Male     Yes          1      Graduate            No             3076
# 2   Male     Yes          2      Graduate            No             5000
# 3   Male     Yes          2      Graduate            No             2340
# 4   Male      No          0  Not Graduate            No             3276
#
#    Credit_History Property_Area  ApplicantIncomeLog  Loan_Amount_Term_Log  \
# 0        1.000000         Urban            8.651724              5.886104
# 1        1.000000         Urban            8.031385              5.886104
# 2        1.000000         Urban            8.517193              5.886104
# 3        0.825444         Urban            7.757906              5.886104
# 4        1.000000         Urban            8.094378              5.886104
#
#    LoanAmountLog  Total_Income_Log
# 0       4.700480          8.651724
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Gender                367 non-null    object
#  1   Married               367 non-null    object
#  2   Dependents            367 non-null    object
#  3   Education             367 non-null    object
#  4   Self_Employed         367 non-null    object
#  5   ApplicantIncome       367 non-null    int64
#  6   Credit_History        367 non-null    float64
#  7   Property_Area         367 non-null    object
#  8   ApplicantIncomeLog    367 non-null    float64
#  9   Loan_Amount_Term_Log  367 non-null    float64
#  10  LoanAmountLog         367 non-null    float64
#  11  Total_Income_Log      367 non-null    float64
# dtypes: float64(5), int64(1), object(6)
# memory usage: 34.5+ KB

# %%
t1=pd.get_dummies(test['Gender'],drop_first=True)
t2=pd.get_dummies(test['Married'],drop_first=True)
t3=pd.get_dummies(test['Dependents'],drop_first=True)
t4=pd.get_dummies(test['Education'],drop_first=True)
t5=pd.get_dummies(test['Self_Employed'],drop_first=True)
t6 =pd.get_dummies(test['Property_Area'],drop_first=True)
df1=pd.concat([test,t1,t2,t3,t4,t5,t6],axis=1)
test=df1

# %%
test.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0   Male     Yes          0      Graduate            No             5720
# 1   Male     Yes          1      Graduate            No             3076
# 2   Male     Yes          2      Graduate            No             5000
# 3   Male     Yes          2      Graduate            No             2340
# 4   Male      No          0  Not Graduate            No             3276
#
#    Credit_History Property_Area  ApplicantIncomeLog  Loan_Amount_Term_Log  \
# 0        1.000000         Urban            8.651724              5.886104
# 1        1.000000         Urban            8.031385              5.886104
# 2        1.000000         Urban            8.517193              5.886104
# 3        0.825444         Urban            7.757906              5.886104
# 4        1.000000         Urban            8.094378              5.886104
#
#    ...  Total_Income_Log  Male    Yes      1      2     3+  Not Graduate  \
# ...

# %%
test.shape
# Out:
# (367, 21)

# %%
cols=['Gender','Married','Dependents','Education','Self_Employed','Property_Area']
test=test.drop(columns=cols,axis=1)

# %%
test.head()
# Out:
#    ApplicantIncome  Credit_History  ApplicantIncomeLog  Loan_Amount_Term_Log  \
# 0             5720        1.000000            8.651724              5.886104
# 1             3076        1.000000            8.031385              5.886104
# 2             5000        1.000000            8.517193              5.886104
# 3             2340        0.825444            7.757906              5.886104
# 4             3276        1.000000            8.094378              5.886104
#
#    LoanAmountLog  Total_Income_Log  Male    Yes      1      2     3+  \
# 0       4.700480          8.651724  True   True  False  False  False
# 1       4.836282          8.428581  True   True   True  False  False
# 2       5.337538          8.824678  True   True  False   True  False
# 3       4.605170          8.494129  True   True  False   True  False
# 4       4.356709          8.094378  True  False  False  False  False
#
#    Not Graduate    Yes  Semiurban  Urban
# 0         False  False      False   True
# ...

# %%
df.head()
# Out:
#   Credit_History Loan_Status  ApplicantIncomeLog  Loan_Amount_Log  \
# 0            1.0           Y            8.674026         4.986426
# 1            1.0           N            8.430109         4.852030
# 2            1.0           Y            8.006368         4.189655
# 3            1.0           Y            7.856707         4.787492
# 4            1.0           Y            8.699515         4.948760
#
#    Total_Income_Log  Loan_Amount_Term_Log  Male    Yes      1      2     3+  \
# 0          8.674026              5.886104  True  False  False  False  False
# 1          8.714568              5.886104  True   True   True  False  False
# 2          8.006368              5.886104  True   True  False  False  False
# 3          8.505323              5.886104  True   True  False  False  False
# 4          8.699515              5.886104  True  False  False  False  False
#
#    Not Graduate    Yes  Semiurban  Urban
# 0         False  False      False   True
# ...

# %%
x = df.drop(columns=['Loan_Status'])   # features
y = df['Loan_Status']                  # target

# %%
y
# Out:
# 0      Y
# 1      N
# 2      Y
# 3      Y
# 4      Y
#       ..
# 609    Y
# 610    Y
# 611    Y
# 612    Y
# 613    N
# Name: Loan_Status, Length: 614, dtype: object

# %%
x
# Out:
#     Credit_History  ApplicantIncomeLog  Loan_Amount_Log  Total_Income_Log  \
# 0              1.0            8.674026         4.986426          8.674026
# 1              1.0            8.430109         4.852030          8.714568
# 2              1.0            8.006368         4.189655          8.006368
# 3              1.0            7.856707         4.787492          8.505323
# 4              1.0            8.699515         4.948760          8.699515
# ..             ...                 ...              ...               ...
# 609            1.0            7.972466         4.262680          7.972466
# 610            1.0            8.320205         3.688879          8.320205
# 611            1.0            8.996157         5.533389          9.025456
# 612            1.0            8.933664         5.231109          8.933664
# 613            0.0            8.430109         4.890349          8.430109
#
#      Loan_Amount_Term_Log   Male    Yes      1      2     3+  Not Graduate  \
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x , y, test_size=0.25, random_state = 42)

# %%
x_train.head()
# Out:
#     Credit_History  ApplicantIncomeLog  Loan_Amount_Log  Total_Income_Log  \
# 92             1.0            8.093462         4.394449          8.535622
# 304            1.0            8.294050         4.941642          8.779557
# 68             1.0            8.867850         4.828314          8.867850
# 15             1.0            8.507143         4.828314          8.507143
# 211            0.0            8.140316         4.852030          8.451053
#
#      Loan_Amount_Term_Log  Male    Yes      1      2     3+  Not Graduate  \
# 92               5.886104  True   True  False   True  False          True
# 304              5.886104  True  False  False  False  False         False
# 68               4.094345  True   True  False  False   True          True
# 15               5.886104  True  False  False  False  False         False
# 211              5.886104  True   True  False  False   True         False
#
#        Yes  Semiurban  Urban
# 92   False      False   True
# ...

# %%
x_test.head()
# Out:
#     Credit_History  ApplicantIncomeLog  Loan_Amount_Log  Total_Income_Log  \
# 350            1.0            9.114160         5.429346          9.114160
# 377            nan            8.368693         4.867534          8.368693
# 163            1.0            8.334952         5.062595          8.633019
# 609            1.0            7.972466         4.262680          7.972466
# 132            1.0            7.907652         4.248495          7.907652
#
#      Loan_Amount_Term_Log   Male    Yes      1      2     3+  Not Graduate  \
# 350              5.886104   True   True  False  False  False         False
# 377              5.886104   True   True  False  False  False         False
# 163              5.886104   True   True  False   True  False         False
# 609              5.886104  False  False  False  False  False         False
# 132              5.886104   True  False  False  False  False         False
#
#        Yes  Semiurban  Urban
# 350  False       True  False
# ...

# %%
y_train.head()
# Out:
# 92     Y
# 304    Y
# 68     Y
# 15     Y
# 211    N
# Name: Loan_Status, dtype: object

# %%
x_train.dtypes
# Out:
# Credit_History           object
# ApplicantIncomeLog      float64
# Loan_Amount_Log         float64
# Total_Income_Log        float64
# Loan_Amount_Term_Log    float64
# Male                       bool
# Yes                        bool
# 1                          bool
# 2                          bool
# 3+                         bool
# Not Graduate               bool
# Yes                        bool
# Semiurban                  bool
# Urban                      bool
# dtype: object

# %% [markdown]
# # model tarining
# ## randomforest classifier

# %%
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier()
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
print("Accuracy is",model.score(x_test,y_test)*100)
# Out:
# Accuracy is 79.22077922077922

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
model2=DecisionTreeClassifier()
model2.fit(x_train,y_train)
print("Accuracy is",model2.score(x_test,y_test)*100)
# Out:
# Accuracy is 72.07792207792207

# %% [markdown]
# # logistic regression

# %%
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LogisticRegression

model3 = make_pipeline(SimpleImputer(strategy='mean'), LogisticRegression())
model3.fit(x_train, y_train)
print("Accuracy is", model3.score(x_test, y_test) * 100)
# Out:
# Accuracy is 77.27272727272727

# %%
import pickle
file=open("model.pkl","wb")
pickle.dump(model,file)

# %%
from sklearn.metrics import confusion_matrix
y_pred=model.predict(x_test)
cm=confusion_matrix(y_test,y_pred)

# %%
cm
# Out:
# array([[25, 29],
#        [ 3, 97]])
